# %%
from babbab import __version__
__version__
# Out:
# '0.1.1'

# %%
from babbab import plot_control_variant_diff

# %%
from babbab.stats import beta_binomial_abtest, bayesian_statement

# %%
trace = beta_binomial_abtest(10000, 100000, 12000, 100000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [control, variant]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 00:01<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 8 seconds.

# %%
plot_control_variant_diff(trace, "Experiment is awesome")
