# %%
# %%bash
#
# cd /home/juan/work/babbab
# pip install . -U
# Out:
# Processing /home/juan/work/babbab
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied, skipping upgrade: flit==3.7.1 in ./lib/python3.8/site-packages (from babbab==0.3.0) (3.7.1)
# Requirement already satisfied, skipping upgrade: pandas==1.4.3 in ./lib/python3.8/site-packages (from babbab==0.3.0) (1.4.3)
# Requirement already satisfied, skipping upgrade: pymc==4.1.2 in ./lib/python3.8/site-packages (from babbab==0.3.0) (4.1.2)
# Requirement already satisfied, skipping upgrade: flit_core>=3.7.1 in ./lib/python3.8/site-packages (from flit==3.7.1->babbab==0.3.0) (3.7.1)
# Requirement already satisfied, skipping upgrade: tomli in ./lib/python3.8/site-packages (from flit==3.7.1->babbab==0.3.0) (1.2.3)
# Requirement already satisfied, skipping upgrade: requests in ./lib/python3.8/site-packages (from flit==3.7.1->babbab==0.3.0) (2.28.1)
# Requirement already satisfied, skipping upgrade: docutils in ./lib/python3.8/site-packages (from flit==3.7.1->babbab==0.3.0) (0.19)
# Requirement already satisfied, skipping upgrade: tomli-w in ./lib/python3.8/site-packages (from flit==3.7.1->babbab==0.3.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in ./lib/python3.8/site-packages (from pandas==1.4.3->babbab==0.3.0) (1.23.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.1 in ./lib/python3.8/site-packages (from pandas==1.4.3->babbab==0.3.0) (2.8.2)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in ./lib/python3.8/site-packages (from pandas==1.4.3->babbab==0.3.0) (2022.1)
# Requirement already satisfied, skipping upgrade: aeppl==0.0.32 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (0.0.32)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (4.3.0)
# Requirement already satisfied, skipping upgrade: aesara==2.7.5 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (2.7.5)
# Requirement already satisfied, skipping upgrade: fastprogress>=0.2.0 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (1.0.2)
# Requirement already satisfied, skipping upgrade: arviz>=0.12.0 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (0.12.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (1.9.0rc2)
# Requirement already satisfied, skipping upgrade: cloudpickle in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (2.1.0)
# Requirement already satisfied, skipping upgrade: cachetools>=4.2.1 in ./lib/python3.8/site-packages (from pymc==4.1.2->babbab==0.3.0) (5.2.0)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in ./lib/python3.8/site-packages (from requests->flit==3.7.1->babbab==0.3.0) (3.3)
# Requirement already satisfied, skipping upgrade: charset-normalizer<3,>=2 in ./lib/python3.8/site-packages (from requests->flit==3.7.1->babbab==0.3.0) (2.1.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in ./lib/python3.8/site-packages (from requests->flit==3.7.1->babbab==0.3.0) (2022.6.15)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in ./lib/python3.8/site-packages (from requests->flit==3.7.1->babbab==0.3.0) (1.26.11)
# Requirement already satisfied, skipping upgrade: six>=1.5 in ./lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas==1.4.3->babbab==0.3.0) (1.16.0)
# Requirement already satisfied, skipping upgrade: filelock in ./lib/python3.8/site-packages (from aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (3.7.1)
# Requirement already satisfied, skipping upgrade: logical-unification in ./lib/python3.8/site-packages (from aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (0.4.5)
# Requirement already satisfied, skipping upgrade: miniKanren in ./lib/python3.8/site-packages (from aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (1.0.3)
# Requirement already satisfied, skipping upgrade: etuples in ./lib/python3.8/site-packages (from aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (0.3.5)
# Requirement already satisfied, skipping upgrade: cons in ./lib/python3.8/site-packages (from aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (0.4.5)
# Requirement already satisfied, skipping upgrade: packaging in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (21.3)
# Requirement already satisfied, skipping upgrade: setuptools>=38.4 in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (44.0.0)
# Requirement already satisfied, skipping upgrade: netcdf4 in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (1.6.0)
# Requirement already satisfied, skipping upgrade: xarray-einstats>=0.2 in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (0.3.0)
# Requirement already satisfied, skipping upgrade: xarray>=0.16.1 in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (2022.6.0rc0)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0 in ./lib/python3.8/site-packages (from arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (3.5.2)
# Requirement already satisfied, skipping upgrade: toolz in ./lib/python3.8/site-packages (from logical-unification->aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (0.12.0)
# Requirement already satisfied, skipping upgrade: multipledispatch in ./lib/python3.8/site-packages (from logical-unification->aesara==2.7.5->pymc==4.1.2->babbab==0.3.0) (0.6.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in ./lib/python3.8/site-packages (from packaging->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (3.0.9)
# Requirement already satisfied, skipping upgrade: cftime in ./lib/python3.8/site-packages (from netcdf4->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (1.6.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in ./lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (1.4.3)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in ./lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (9.2.0)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in ./lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (4.34.4)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in ./lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.12.0->pymc==4.1.2->babbab==0.3.0) (0.11.0)
# Building wheels for collected packages: babbab
#   Building wheel for babbab (PEP 517): started
#   Building wheel for babbab (PEP 517): finished with status 'done'
#   Created wheel for babbab: filename=babbab-0.3.0-py2.py3-none-any.whl size=6067 sha256=d5de154caae10d47ed9a2eee1074f87965c892bd8b920148e9b808ed82083da1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i36bdp5f/wheels/d0/05/24/826ffd5cb65ac4911dc4f9aa677d3cff194172f52d1234825d
# Successfully built babbab
# Installing collected packages: babbab
#   Attempting uninstall: babbab
#     Found existing installation: babbab 0.3.0
#     Uninstalling babbab-0.3.0:
#       Successfully uninstalled babbab-0.3.0
# Successfully installed babbab-0.3.0

# %%
import babbab as bab
bab.__version__
# Out:
# '0.3.0'

# %%
control_sold_subscriptions = 200 
control_users = 40316
variant_sold_subscriptions = 250
variant_users = 40567

fig, statement, trace = bab.quick_analysis(control_sold_subscriptions, control_users, variant_sold_subscriptions, variant_users);
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [control, variant]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 00:03<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 5_000 draw iterations (2_000 + 10_000 draws total) took 4 seconds.

# %%
statement
# Out:
# 'There is a 95% chance that the difference forVariant with respect to Control is between 10.1% and 40.5%'

# %%
type(trace)
# Out:
# arviz.data.inference_data.InferenceData

# %%
trace
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data
